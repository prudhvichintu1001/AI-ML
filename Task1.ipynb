# %% [markdown]
# <a href="https://colab.research.google.com/github/prudhvichintu1001/AI-ML/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importing the required libraries

# %%
data = pd.read_csv("/Bank Customer Churn Prediction.csv")
data
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15634602           619   France  Female   42       2       0.00
# 1        15647311           608    Spain  Female   41       1   83807.86
# 2        15619304           502   France  Female   42       8  159660.80
# 3        15701354           699   France  Female   39       1       0.00
# 4        15737888           850    Spain  Female   43       2  125510.82
# ...           ...           ...      ...     ...  ...     ...        ...
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %% [markdown]
# loading the data set and displaying the contents of the data set

# %%
data.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %%
data.tail()
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# 9995                2            1              0          96270.64      0
# 9996                1            1              1         101699.77      0
# 9997                1            0              1          42085.58      1
# 9998                2            1              0          92888.52      1
# 9999                1            1              0          38190.78      0

# %% [markdown]
# this command displays the last 5 customer ids of the table

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  object
#  3   gender            10000 non-null  object
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %% [markdown]
# This command gives the type of the data like int, float etc...

# %%
data.nunique()
# Out:
# customer_id         10000
# credit_score          460
# country                 3
# gender                  2
# age                    70
# tenure                 11
# balance              6382
# products_number         4
# credit_card             2
# active_member           2
# estimated_salary     9999
# churn                   2
# dtype: int64

# %% [markdown]
# This command Gives the no of unique elements

# %%
data.isnull().sum()
# Out:
# customer_id         0
# credit_score        0
# country             0
# gender              0
# age                 0
# tenure              0
# balance             0
# products_number     0
# credit_card         0
# active_member       0
# estimated_salary    0
# churn               0
# dtype: int64

# %% [markdown]
# This command gives the no of missing elements

# %%
(data.isnull().sum()/(len(data)))*100
# Out:
# customer_id         0.0
# credit_score        0.0
# country             0.0
# gender              0.0
# age                 0.0
# tenure              0.0
# balance             0.0
# products_number     0.0
# credit_card         0.0
# active_member       0.0
# estimated_salary    0.0
# churn               0.0
# dtype: float64

# %% [markdown]
# This command gives the percentage of the missing elements

# %%
data2 = data.drop(['credit_score','products_number'],axis=1)
data2
# Out:
#       customer_id  country  gender  age  tenure    balance  credit_card  \
# 0        15634602   France  Female   42       2       0.00            1
# 1        15647311    Spain  Female   41       1   83807.86            0
# 2        15619304   France  Female   42       8  159660.80            1
# 3        15701354   France  Female   39       1       0.00            0
# 4        15737888    Spain  Female   43       2  125510.82            1
# ...           ...      ...     ...  ...     ...        ...          ...
# 9995     15606229   France    Male   39       5       0.00            1
# 9996     15569892   France    Male   35      10   57369.61            1
# 9997     15584532   France  Female   36       7       0.00            0
# 9998     15682355  Germany    Male   42       3   75075.31            1
# 9999     15628319   France  Female   28       4  130142.79            1
#
#       active_member  estimated_salary  churn
# 0                 1         101348.88      1
# ...

# %% [markdown]
# This command removes credit score and product number from the original data set because they are not necessary for the calculation of the churn. we need to know whether they are active member or not

# %%
import pandas as pd
df = data2
df['churn'] = 1
df.loc[df['active_member'] == 1, 'churn'] = 0
print(df.head())
# Out:
#    customer_id country  gender  age  tenure    balance  credit_card  \
# 0     15634602  France  Female   42       2       0.00            1
# 1     15647311   Spain  Female   41       1   83807.86            0
# 2     15619304  France  Female   42       8  159660.80            1
# 3     15701354  France  Female   39       1       0.00            0
# 4     15737888   Spain  Female   43       2  125510.82            1
#
#    active_member  estimated_salary  churn
# 0              1         101348.88      0
# 1              1         112542.58      0
# 2              0         113931.57      1
# 3              0          93826.63      1
# 4              1          79084.10      0

# %% [markdown]
# by applying the logic we can get the churn value and after that we are displaying the data set

# %%
df
# Out:
#       customer_id  country  gender  age  tenure    balance  credit_card  \
# 0        15634602   France  Female   42       2       0.00            1
# 1        15647311    Spain  Female   41       1   83807.86            0
# 2        15619304   France  Female   42       8  159660.80            1
# 3        15701354   France  Female   39       1       0.00            0
# 4        15737888    Spain  Female   43       2  125510.82            1
# ...           ...      ...     ...  ...     ...        ...          ...
# 9995     15606229   France    Male   39       5       0.00            1
# 9996     15569892   France    Male   35      10   57369.61            1
# 9997     15584532   France  Female   36       7       0.00            0
# 9998     15682355  Germany    Male   42       3   75075.31            1
# 9999     15628319   France  Female   28       4  130142.79            1
#
#       active_member  estimated_salary  churn
# 0                 1         101348.88      0
# ...

# %%
data2.describe().T
# Out:
#                     count          mean           std          min  \
# customer_id       10000.0  1.569094e+07  71936.186123  15565701.00
# age               10000.0  3.892180e+01     10.487806        18.00
# tenure            10000.0  5.012800e+00      2.892174         0.00
# balance           10000.0  7.648589e+04  62397.405202         0.00
# credit_card       10000.0  7.055000e-01      0.455840         0.00
# active_member     10000.0  5.151000e-01      0.499797         0.00
# estimated_salary  10000.0  1.000902e+05  57510.492818        11.58
# churn             10000.0  4.849000e-01      0.499797         0.00
#
#                           25%           50%           75%          max
# customer_id       15628528.25  1.569074e+07  1.575323e+07  15815690.00
# age                     32.00  3.700000e+01  4.400000e+01        92.00
# tenure                   3.00  5.000000e+00  7.000000e+00        10.00
# balance                  0.00  9.719854e+04  1.276442e+05    250898.09
# ...

# %% [markdown]
# Gives the statistical distributions

# %%
data2.describe(include='all').T
# Out:
#                     count unique     top  freq           mean           std  \
# customer_id       10000.0    NaN     NaN   NaN  15690940.5694  71936.186123
# country             10000      3  France  5014            NaN           NaN
# gender              10000      2    Male  5457            NaN           NaN
# age               10000.0    NaN     NaN   NaN        38.9218     10.487806
# tenure            10000.0    NaN     NaN   NaN         5.0128      2.892174
# balance           10000.0    NaN     NaN   NaN   76485.889288  62397.405202
# credit_card       10000.0    NaN     NaN   NaN         0.7055       0.45584
# active_member     10000.0    NaN     NaN   NaN         0.5151      0.499797
# estimated_salary  10000.0    NaN     NaN   NaN  100090.239881  57510.492818
# churn             10000.0    NaN     NaN   NaN         0.4849      0.499797
#
#                          min          25%         50%          75%         max
# ...

# %% [markdown]
# This commands provides the statistics summary of all data, include object, category etc

# %%
import numpy as np
cat_cols=data2.select_dtypes(include=['object']).columns
num_cols = data2.select_dtypes(include=np.number).columns.tolist()     #Catagorize the Variables i.e Categorial Variables and Numerical Variables
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['country', 'gender'], dtype='object')
# Numerical Variables:
# ['customer_id', 'age', 'tenure', 'balance', 'credit_card', 'active_member', 'estimated_salary', 'churn']

# %% [markdown]
# This command categorises the variables into category variables and numerical variables

# %%
for col in num_cols:
    print(col)
    print('Skew :', round(data[col].skew(), 2))
    plt.figure(figsize = (10, 4))
    plt.subplot(1, 2, 1)                                        #plotting using the histogram and box plot
    data[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=data[col])
    plt.show()
# Out:
# customer_id
# Skew : 0.0
# age
# Skew : 1.01
# tenure
# Skew : 0.01
# balance
# Skew : -0.14
# credit_card
# Skew : -0.9
# active_member
# Skew : -0.06
# estimated_salary
# Skew : 0.0
# churn
# Skew : 1.47

# %% [markdown]
# Plotting the graph using histogram and box plot

# %%
fig, axes = plt.subplots(3, 2, figsize = (18, 18))
fig.suptitle('Bar plot for all categorical variables in the dataset')
sns.countplot(ax = axes[0, 0], x = 'country', data = data2, color = 'blue',
              order = data['country'].value_counts().index);
sns.countplot(ax = axes[0, 1], x = 'gender', data = data2, color = 'blue',
              order = data['gender'].value_counts().index);
sns.countplot(ax = axes[1, 0], x = 'age', data = data2, color = 'blue',
              order = data['age'].value_counts().index);
sns.countplot(ax = axes[1, 1], x = 'tenure', data = data2, color = 'blue',
              order = data['tenure'].value_counts().index);
sns.countplot(ax = axes[2, 0], x = 'active_member', data = data2, color = 'blue',
              order = data['active_member'].head(20).value_counts().index);
sns.countplot(ax = axes[2, 1], x = 'churn', data = data2, color = 'blue',
              order = data['churn'].head(20).value_counts().index);
axes[1][1].tick_params(labelrotation=45);
axes[2][0].tick_params(labelrotation=90);
axes[2][1].tick_params(labelrotation=90);

# %% [markdown]
# This command gives the bar plot
